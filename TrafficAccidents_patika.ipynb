# %% [markdown]
# # 🚗Traffic Accidents Data Analysis

# %% [markdown]
# This project focuses on analysis and visualization of UK Road Accidents dataset. Pandas and NumPy libraries were utilized for data analysis, Seaborn was used for visualization.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/accidents_2012_to_2014.csv")
# Out:
# /tmp/ipython-input-24-3203601481.py:1: DtypeWarning: Columns (31) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("/content/accidents_2012_to_2014.csv")

# %% [markdown]
# ## Data Overview

# %%
df.shape
# Out:
# (464697, 33)

# %%
df.head()
# Out:
#   Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# 0  201201BS70001                 527200                  178760  -0.169101
# 1  201201BS70002                 524930                  181430  -0.200838
# 2  201201BS70003                 525860                  178080  -0.188636
# 3  201201BS70004                 524980                  181030  -0.200259
# 4  201201BS70005                 526170                  179200  -0.183773
#
#     Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  51.493429             1                  3                   2
# 1  51.517931             1                  3                   2
# 2  51.487618             1                  3                   2
# 3  51.514325             1                  3                   1
# 4  51.497614             1                  3                   1
#
#    Number_of_Casualties        Date  ...  \
# 0                     1  19/01/2012  ...
# ...

# %%
df.tail()
# Out:
#        Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  \
# 464692       2.01E+12                 310037                  597647
# 464693       2.01E+12                 321509                  574063
# 464694       2.01E+12                 321337                  566365
# 464695       2.01E+12                 323869                  566853
# 464696       2.01E+12                 314072                  579971
#
#         Longitude   Latitude  Police_Force  Accident_Severity  \
# 464692  -3.417278  55.264773            98                  2
# 464693  -3.230255  55.054855            98                  3
# 464694  -3.230826  54.985668            98                  3
# 464695  -3.191397  54.990446            98                  2
# 464696  -3.348426  55.106700            98                  3
#
#         Number_of_Vehicles  Number_of_Casualties        Date  ...  \
# 464692                   2                     1  07/12/2014  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 464697 entries, 0 to 464696
# Data columns (total 33 columns):
#  #   Column                                       Non-Null Count   Dtype
# ---  ------                                       --------------   -----
#  0   Accident_Index                               464697 non-null  object
#  1   Location_Easting_OSGR                        464697 non-null  int64
#  2   Location_Northing_OSGR                       464697 non-null  int64
#  3   Longitude                                    464697 non-null  float64
#  4   Latitude                                     464697 non-null  float64
#  5   Police_Force                                 464697 non-null  int64
#  6   Accident_Severity                            464697 non-null  int64
#  7   Number_of_Vehicles                           464697 non-null  int64
#  8   Number_of_Casualties                         464697 non-null  int64
# ...

# %% [markdown]
# ## Missing Values

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Junction_Detail                                464697
# Carriageway_Hazards                            456850
# Special_Conditions_at_Site                     454387
# Junction_Control                               178610
# LSOA_of_Accident_Location                       28718
# Road_Surface_Conditions                           755
# Time                                               13
# Did_Police_Officer_Attend_Scene_of_Accident         2
# Accident_Index                                      0
# Number_of_Casualties                                0
# Location_Easting_OSGR                               0
# Longitude                                           0
# Location_Northing_OSGR                              0
# Police_Force                                        0
# Accident_Severity                                   0
# Number_of_Vehicles                                  0
# Latitude                                            0
# ...

# %%
missing = df. isnull().sum()
percent_missing = (missing / len(df)) * 100
missing_df = pd.DataFrame ({'Missing Values': missing, 'percent': percent_missing})
missing_df.sort_values(by='percent', ascending=False, inplace=True)
missing_df
# Out:
#                                              Missing Values     percent
# Junction_Detail                                      464697  100.000000
# Carriageway_Hazards                                  456850   98.311373
# Special_Conditions_at_Site                           454387   97.781350
# Junction_Control                                     178610   38.435798
# LSOA_of_Accident_Location                             28718    6.179941
# Road_Surface_Conditions                                 755    0.162471
# Time                                                     13    0.002798
# Did_Police_Officer_Attend_Scene_of_Accident               2    0.000430
# Accident_Index                                            0    0.000000
# Number_of_Casualties                                      0    0.000000
# Location_Easting_OSGR                                     0    0.000000
# Longitude                                                 0    0.000000
# ...

# %% [markdown]
# Columns that have mostly missing values are dropped.

# %%
df.drop(columns=[
    'Junction_Detail',
    'Carriageway_Hazards',
    'Special_Conditions_at_Site',
    'Junction_Control'
], inplace=True, errors='ignore')

# %%
df.shape
# Out:
# (464697, 29)

# %% [markdown]
# ## Visualization

# %% [markdown]
# Yearly accident count is calculated.

# %%
df['Year'].value_counts().sort_index().plot(kind='bar')
plt.title('Accident Count per Year')
plt.xlabel('Year')
plt.ylabel('Accident Count')
plt.show()

# %% [markdown]
# Distribution of accidents based on weekdays is investigated.

# %%
day_map = {
    1: 'Sunday', 2: 'Monday', 3: 'Tuesday',
    4: 'Wednesday', 5: 'Thursday', 6: 'Friday', 7: 'Saturday'
}

df['Day_of_Week'] = df['Day_of_Week'].map(day_map)

# Order the days explicitly
ordered_days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
day_counts = df['Day_of_Week'].value_counts().reindex(ordered_days)

# Plot pie chart
colors = sns.color_palette("Set2")

plt.figure(figsize=(8, 8))
plt.pie(
    day_counts,
    labels=ordered_days,
    autopct='%1.1f%%',
    startangle=140,
    colors=colors
)
plt.title('Distribution of Accidents by Week Day')
plt.axis('equal')  # Equal aspect ratio ensures pie is drawn as a circle
plt.show()

# %% [markdown]
# Accidents appear to be distributed mostly equally throughout the week.

# %% [markdown]
# Hourly distribution of accidents is investigated.

# %%
df['Hour'] = pd.to_datetime(df['Time'], format='%H:%M').dt.hour

hour_counts = df['Hour'].value_counts().sort_index()

colors = sns.color_palette("Set2", n_colors=len(hour_counts))

plt.figure(figsize=(10, 5))
plt.bar(hour_counts.index, hour_counts.values, color=colors)
plt.title('Number of Accidents by Hour')
plt.xlabel('Hour of the Day')
plt.ylabel('Number of Accidents')
plt.xticks(range(0, 24))
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# As expected, most accidents accumulate during work hours.

# %% [markdown]
# Distribution of accidents based on light conditions are investigated.

# %%
light_counts = df['Light_Conditions'].value_counts()

colors = sns.color_palette("Set2", n_colors=len(light_counts))

plt.figure(figsize=(10, 5))
plt.bar(light_counts.index, light_counts.values, color=colors)
plt.title('Number of Accidents by Light Conditions')
plt.xlabel('Light Condition')
plt.ylabel('Number of Accidents')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# Most accidents occur during day light.

# %% [markdown]
# Distribution of casualties is investigated.

# %%
casualty_counts = df['Number_of_Casualties'].value_counts().sort_index()

# Generate a color palette with the right number of colors
colors = sns.color_palette("Set2", n_colors=len(casualty_counts))

# Plot using matplotlib to apply colors
plt.figure(figsize=(10, 5))
plt.bar(casualty_counts.index.astype(str), casualty_counts.values, color=colors)
plt.title('Distribution of Accidents by Number of Casualties')
plt.xlabel('Number of Casualties')
plt.ylabel('Number of Accidents')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# Majority of accidents have 1 casualy. Multiple casualties are rare.

# %%
weather_counts = df['Weather_Conditions'].value_counts()

# Generate color palette with matching number of colors
colors = sns.color_palette("Set2", n_colors=len(weather_counts))

# Plot using matplotlib to control colors
plt.figure(figsize=(10, 5))
plt.bar(weather_counts.index, weather_counts.values, color=colors)
plt.title('Number of Accidents by Weather Condition')
plt.xlabel('Weather Condition')
plt.ylabel('Number of Accidents')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# Most accidents occurred during fine weather conditions.
